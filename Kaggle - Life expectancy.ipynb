# %%
# !pip install -q kaggle

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fa3b3897-f3b4-4537-9dc6-2881e7562494" name="files[]" multiple disabled />
#      <output id="result-fa3b3897-f3b4-4537-9dc6-2881e7562494">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d kumarajarshi/life-expectancy-who
# Out:
# ...
#   0% 0.00/119k [00:00<?, ?B/s]
# 100% 119k/119k [00:00<00:00, 36.4MB/s]

# %%
import pandas as pd

df = pd.read_csv('/content/life-expectancy-who.zip', header=0, sep=',', quotechar='"')

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.describe()
# Out:
#               Year  ...    Schooling
# count  2938.000000  ...  2775.000000
# mean   2007.518720  ...    11.992793
# std       4.613841  ...     3.358920
# min    2000.000000  ...     0.000000
# 25%    2004.000000  ...    10.100000
# 50%    2008.000000  ...    12.300000
# 75%    2012.000000  ...    14.300000
# max    2015.000000  ...    20.700000
#
# [8 rows x 20 columns]

# %%
df.head()
# Out:
#        Country  Year  ... Income composition of resources  Schooling
# 0  Afghanistan  2015  ...                           0.479       10.1
# 1  Afghanistan  2014  ...                           0.476       10.0
# 2  Afghanistan  2013  ...                           0.470        9.9
# 3  Afghanistan  2012  ...                           0.463        9.8
# 4  Afghanistan  2011  ...                           0.454        9.5
#
# [5 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.subplots(figsize=(20, 10))
sns.barplot(x=df['Year'],y=df.iloc[:,3],data= df)

# %%
india = df[df['Country'] == 'India']

# %%
india.shape
# Out:
# (16, 22)

# %%
plt.subplots(figsize=(20, 10))
sns.barplot(x=india['Year'],y=india.iloc[:,3],data= df)

# %%
india
# Out:
#      Country  Year  ... Income composition of resources  Schooling
# 1186   India  2015  ...                           0.615       11.6
# 1187   India  2014  ...                           0.607       11.6
# 1188   India  2013  ...                           0.599       11.5
# 1189   India  2012  ...                           0.590       11.3
# 1190   India  2011  ...                           0.580       10.8
# 1191   India  2010  ...                           0.569       10.4
# 1192   India  2009  ...                           0.563       10.5
# 1193   India  2008  ...                           0.556       10.2
# 1194   India  2007  ...                           0.546        9.9
# 1195   India  2006  ...                           0.536        9.7
# 1196   India  2005  ...                           0.526        9.4
# 1197   India  2004  ...                           0.518        9.2
# 1198   India  2003  ...                           0.505        8.6
# ...
