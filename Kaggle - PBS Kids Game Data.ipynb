# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-81995468-a8b0-45b1-89d7-244364eb384c" name="files[]" multiple disabled />
#      <output id="result-81995468-a8b0-45b1-89d7-244364eb384c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
pip install kaggle

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle competitions download -c data-science-bowl-2019

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import seaborn as sns

train = pd.read_csv('/content/train_labels.csv.zip', header=0, sep=',', quotechar='"')
train2 = pd.read_csv('/content/train.csv.zip', header=0, sep=',', quotechar='"')
subm = pd.read_csv('/content/sample_submission.csv', header=0, sep=',', quotechar='"')
spex = pd.read_csv('/content/specs.csv', header=0, sep=',', quotechar='"')
test = pd.read_csv('/content/test.csv.zip', header=0, sep=',', quotechar='"')

# %%
train
# Out:
#            game_session installation_id  ...  accuracy  accuracy_group
# 0      6bdf9623adc94d89        0006a69f  ...  1.000000               3
# 1      77b8ee947eb84b4e        0006a69f  ...  0.000000               0
# 2      901acc108f55a5a1        0006a69f  ...  1.000000               3
# 3      9501794defd84e4d        0006a69f  ...  0.500000               2
# 4      a9ef3ecb3d1acc6a        0006a69f  ...  1.000000               3
# ...                 ...             ...  ...       ...             ...
# 17685  c996482b11d149dd        ffc90c32  ...  1.000000               3
# 17686  b05a02b52d5c1f4c        ffd2871d  ...  1.000000               3
# 17687  5448d652309a6324        ffeb0b1b  ...  0.333333               1
# 17688  a6885ab824fbc32c        ffeb0b1b  ...  0.000000               0
# 17689  dadd1a4d8ac68ab0        ffeb0b1b  ...  0.333333               1
#
# [17690 rows x 7 columns]

# %%
train[train['game_session'] == '45bb1e1b6b50c07b']
# Out:
# Empty DataFrame
# Columns: [game_session, installation_id, title, num_correct, num_incorrect, accuracy, accuracy_group]
# Index: []

# %%
train2[train2['game_session'] == '460e8bdc2822b340']

# %%
train2
# Out:
#           event_id      game_session  ...      type         world
# 0         27253bdc  45bb1e1b6b50c07b  ...      Clip          NONE
# 1         27253bdc  17eeb7f223665f53  ...      Clip     MAGMAPEAK
# 2         77261ab5  0848ef14a8dc6892  ...  Activity     MAGMAPEAK
# 3         b2dba42b  0848ef14a8dc6892  ...  Activity     MAGMAPEAK
# 4         1bb5fbdb  0848ef14a8dc6892  ...  Activity     MAGMAPEAK
# ...            ...               ...  ...       ...           ...
# 11341037  ab3136ba  c09b94eebfdf50a6  ...      Game     MAGMAPEAK
# 11341038  27253bdc  6ad8ab25003ef1b0  ...      Clip  CRYSTALCAVES
# 11341039  27253bdc  71904dca23b982c6  ...      Clip  CRYSTALCAVES
# 11341040  27253bdc  2267b18f069e875a  ...      Clip  CRYSTALCAVES
# 11341041  27253bdc  f31950f549d7c242  ...      Clip   TREETOPCITY
#
# [11341042 rows x 11 columns]

# %%
test.head(2)
# Out:
#    event_id      game_session  ...  type      world
# 0  27253bdc  0ea9ecc81a565215  ...  Clip       NONE
# 1  27253bdc  c1ea43d8b8261d27  ...  Clip  MAGMAPEAK
#
# [2 rows x 11 columns]

# %%
spex.head(2)
# Out:
#    event_id  ...                                               args
# 0  2b9272f4  ...  [{"name":"game_time","type":"int","info":"mill...
# 1  df4fe8b6  ...  [{"name":"game_time","type":"int","info":"mill...
#
# [2 rows x 3 columns]
